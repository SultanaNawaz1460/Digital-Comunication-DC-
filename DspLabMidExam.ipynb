# %% [markdown]
# <a href="https://colab.research.google.com/github/SultanaNawaz1460/Digital-Comunication-DC-/blob/main/DspLabMidExam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DSP LAB MID EXAM**

# %% [markdown]
# #H(z)= 1 divided by 1−0.9z^-1
# # a)  find out  the z transform of the alone draw zero and poles on the unit circle
# #b) find out the freq response of the system
# #c)determine the stability of the both system give the sepearte cod efor the a part and b part

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal
#part a

def plot_pz_response_A():
    num = [1]
    den = [1, -0.9]

    system = signal.dlti(num, den, dt=True)

    poles = system.poles
    zeros = system.zeros

    # Plot Pole-Zero
    plt.figure(figsize=(6,6))
    plt.scatter(np.real(zeros), np.imag(zeros), marker='o', color='blue', label='Zeros')
    plt.scatter(np.real(poles), np.imag(poles), marker='x', color='red', label='Poles')

    # Draw unit circle
    unit_circle = plt.Circle((0, 0), 1, color='gray', fill=False, linestyle='--')
    plt.gca().add_patch(unit_circle)

    plt.axhline(0, color='black', lw=0.5)
    plt.axvline(0, color='black', lw=0.5)
    plt.xlabel("Real")
    plt.ylabel("Imaginary")
    plt.title("Pole-Zero Plot (System A)")
    plt.grid()
    plt.legend()
    plt.axis("equal")
    plt.show()
#part c

    # Stability check
    stable = all(np.abs(poles) < 1)
    print("System A is", "Stable" if stable else "Unstable")

plot_pz_response_A()
# part b

def freq_response_A():
    num = [1]
    den = [1, -0.9]

    system = signal.dlti(num, den, dt=True)
    w, h = signal.dfreqresp(system)

    plt.figure()
    plt.plot(w, 20 * np.log10(np.abs(h)))
    plt.title("Frequency Response (System A)")
    plt.xlabel("Frequency (rad/sample)")
    plt.ylabel("Magnitude (dB)")
    plt.grid()
    plt.show()

freq_response_A()
# Out:
# System A is Stable

# %% [markdown]
# #H(z)= 1 - z^-1 divided by  1−0.563z^−1+0.158z^−2
# #a)  find out  the z transform of the alone draw zero and poles on the unit circle
# #b) find out the freq response of the system
# #c)determine the stability of the both system give the sepearte cod efor the a part and b part

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal
# PART A
def plot_pz_response_B():
    num = [1, -1]              # Numerator: 1 - z^-1
    den = [1, -0.563, 0.158]   # Denominator: 1 - 0.563z^-1 + 0.158z^-2

    system = signal.dlti(num, den, dt=True)
    poles = system.poles
    zeros = system.zeros

    # Plot Pole-Zero
    plt.figure(figsize=(6,6))
    plt.scatter(np.real(zeros), np.imag(zeros), marker='o', color='blue', label='Zeros')
    plt.scatter(np.real(poles), np.imag(poles), marker='x', color='red', label='Poles')

    # Draw unit circle
    unit_circle = plt.Circle((0, 0), 1, color='gray', fill=False, linestyle='--')
    plt.gca().add_patch(unit_circle)

    plt.axhline(0, color='black', lw=0.5)
    plt.axvline(0, color='black', lw=0.5)
    plt.xlabel("Real")
    plt.ylabel("Imaginary")
    plt.title("Pole-Zero Plot (System B)")
    plt.grid()
    plt.legend()
    plt.axis("equal")
    plt.show()
# PART C
    # Stability check
    stable = all(np.abs(poles) < 1)
    print("System B is", "Stable" if stable else "Unstable")

plot_pz_response_B()
# PART B
# freq_Resonse

def freq_response_B():
    num = [1, -1]
    den = [1, -0.563, 0.158]

    system = signal.dlti(num, den, dt=True)
    w, h = signal.dfreqresp(system)

    plt.figure()
    plt.plot(w, 20 * np.log10(np.abs(h)))
    plt.title("Frequency Response (System B)")
    plt.xlabel("Frequency (rad/sample)")
    plt.ylabel("Magnitude (dB)")
    plt.grid()
    plt.show()

freq_response_B()
# Out:
# System B is Stable
# <ipython-input-5-79aab1c722ef>:45: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(w, 20 * np.log10(np.abs(h)))

# %% [markdown]
# ## A PART

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal

def plot_pz_response_A():

    num = [1]
    den = [1, -0.9]


    system = signal.dlti(num, den, dt=True)


    poles = system.poles
    zeros = system.zeros

    # Plot Pole-Zero
    plt.figure(figsize=(6, 6))
    plt.scatter(np.real(zeros), np.imag(zeros), marker='o', color='blue', label='Zeros')
    plt.scatter(np.real(poles), np.imag(poles), marker='x', color='red', label='Poles')

    # Draw unit circle
    unit_circle = plt.Circle((0, 0), 1, color='gray', fill=False, linestyle='--')
    plt.gca().add_patch(unit_circle)

    plt.axhline(0, color='black', lw=0.5)
    plt.axvline(0, color='black', lw=0.5)
    plt.xlabel("Real")
    plt.ylabel("Imaginary")
    plt.title("Pole-Zero Plot (System A)")
    plt.grid()
    plt.legend()
    plt.axis("equal")
    plt.show()

    # Stability check
    stable = all(np.abs(poles) < 1)
    print("System A is", "Stable" if stable else "Unstable")

def freq_response_A_full():

    num = [1]
    den = [1, -0.9]

    # Create frequency range from -π to π
    w = np.linspace(-np.pi, np.pi, 1024)

    # Compute frequency response using freqz
    w, h = signal.freqz(num, den, worN=w)

    # Plot Magnitude Response
    plt.figure()
    plt.plot(w, 20 * np.log10(np.abs(h)))
    plt.title("Frequency Response (System A) - Full Range")
    plt.xlabel("Frequency (rad/sample)")
    plt.ylabel("Magnitude (dB)")
    plt.grid()
    plt.show()


plot_pz_response_A()
freq_response_A_full()
# Out:
# System A is Stable

# %% [markdown]
# # PART B

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal

#Pole-Zero Plot
def plot_pz_response_B():
    num = [1, -1]
    den = [1, -0.563, 0.158]

    system = signal.dlti(num, den, dt=True)
    poles = system.poles
    zeros = system.zeros

    plt.figure(figsize=(6, 6))
    plt.scatter(np.real(zeros), np.imag(zeros), marker='o', color='blue', label='Zeros')
    plt.scatter(np.real(poles), np.imag(poles), marker='x', color='red', label='Poles')

    unit_circle = plt.Circle((0, 0), 1, color='gray', fill=False, linestyle='--')
    plt.gca().add_patch(unit_circle)

    plt.axhline(0, color='black', lw=0.5)
    plt.axvline(0, color='black', lw=0.5)
    plt.xlabel("Real")
    plt.ylabel("Imaginary")
    plt.title("Pole-Zero Plot (System B)")
    plt.grid()
    plt.legend()
    plt.axis("equal")
    plt.show()

    # Stability check
    stable = all(np.abs(poles) < 1)
    print("System B is", "Stable" if stable else "Unstable")


# Frequency Response from -π to π
def freq_response_B():
    num = [1, -1]
    den = [1, -0.563, 0.158]

    w = np.linspace(-np.pi, np.pi, 1024)
    w, h = signal.freqz(num, den, worN=w)

    plt.figure()
    plt.plot(w, 20 * np.log10(np.abs(h)))
    plt.title("Frequency Response (System B)")
    plt.xlabel("Frequency (rad/sample)")
    plt.ylabel("Magnitude (dB)")

    plt.grid()
    plt.show()


# Run the functions
plot_pz_response_B()
freq_response_B()
# Out:
# System B is Stable
